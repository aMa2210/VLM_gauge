# %%
import time
import os
from google import genai
import pandas as pd
from google.genai import types
file_path = 'Dataset/1_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
graduation_interval = df.loc['graduation_interval', 'Content / Example']

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])
# model_name = "gemini-3-flash-preview"
model_name = "gemini-3-pro-preview"


VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]
output_dir = f'Results_new/1.- Analog Dial Gauge{model_name}'
os.makedirs(output_dir, exist_ok=True)
    
for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    
    output_file = os.path.join(output_dir, f'{seq_id}_Raw_Results.xlsx')
    if os.path.exists(output_file):
        print(f"Skipping: {seq_id} (the result file already exists)")
        continue
    
    print(f"\n{'='*20} Processing: {seq_id} {'='*20}")

    print("Uploading...")
    program_start_time = time.time()
    myfile = client.files.upload(file=f"Dataset/1.- Analog Dial Gauge/{seq_id}.mp4")
    print(f"Uploaded: {myfile.name}")

    while True:
        file_status = client.files.get(name=myfile.name)

        if file_status.state == "ACTIVE":
            print("Succeed")
            break
        elif file_status.state == "FAILED":
            raise Exception("Failed (State: FAILED)")

        print("Still processing, waiting...")
        time.sleep(5)

        
# CoT prompt
    message = f'''
    ROLE: Expert Industrial Metrology Assistant

    PROTOCOL: See-Think-Confirm
    1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
    2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
    3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
    CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
    TASK: Extract a high-precision time-series of readings from the video.

    INSTRUMENT METADATA:
    - Gauge Type:{gauge_type} | Unit: {unit} 
    - Graduation Interval: {graduation_interval}
    - Calibrated Range: [{reading_start}, {reading_end}]

    SAMPLING PROTOCOL:
    - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
    - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
    - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
    - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

    RESPONSE REQUIREMENT:
    Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}
    '''

# naive prompt
#     message = f'''
#     ROLE: Expert Industrial Metrology Assistant

#     TASK: Read the analog gauge values from the video at specific time intervals.

#     INSTRUMENT METADATA:
#     - Gauge Type:{gauge_type} | Unit: {unit} 
#     - Graduation Interval: {graduation_interval}
#     - Calibrated Range: [{reading_start}, {reading_end}]

#     SAMPLING REQUIREMENTS:
#     - Use the digital chronometer shown in the video for timing.
#     - Start reading from the first 200ms integer increment.
#     - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
#     - Continue until the video ends.

#     OUTPUT FORMAT:
#     Return only a JSON array of objects: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     '''
    print("Generatng...")

    response = client.models.generate_content(
        model=model_name, 
        contents=[myfile, message],
        config=types.GenerateContentConfig(
            temperature=0.0,
            thinking_config=types.ThinkingConfig(thinking_level="high")
        )
    )
    # "Identify the analog gauge and output a timestamped table of its readings based on the visible dial markings."
    print(response.text)


    program_end_time = time.time()
    total_duration = program_end_time - program_start_time
    print(total_duration)

    df_output = pd.DataFrame([{
        "sequence_id": seq_id,
        "raw_model_response": response.text,
        "total_duration_sec": round(total_duration, 2),
        "model_name": model_name,
    }])

    df_output.to_excel(output_file, index=False)
# Out:
# ==================== Processing: V1_5 divisions_per_second ====================
# Uploading...
# Uploaded: files/67zsskpi2d6p
# Still processing, waiting...
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 1000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 1200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 1400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 1600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 1800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 2000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 2200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 12000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 12200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 12400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 12600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 12800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 13000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 13200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 13400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 13600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 13800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 14000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 14200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 14400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 14600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 14800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 15000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 15200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 15400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 15600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 15800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 16000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 16200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 16400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 16600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 16800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 17000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 17200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 17400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 17600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 17800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 18000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 18200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 18400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 18600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 18800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 19000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 19200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 19400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 19600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 19800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 20000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 20200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 20400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 20600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 20800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 21000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 21200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 21400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 21600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 21800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 22000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 22200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 22400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 22600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 22800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 23000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 23200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 23400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 23600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 23800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 24000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 24200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 24400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 24600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 24800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 25000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 25200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 25400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 25600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 25800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 26000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 26200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 26400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 26600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 26800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 27000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 27200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 27400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 27600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 27800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 28000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 28200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 28400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 28600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 28800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 29000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 29200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 29400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 29600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 29800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 30000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 30200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 30400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 30600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 30800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 31000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 31200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 31400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 31600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 31800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 32000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 32200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 32400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 32600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 32800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 33000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 33200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 33400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 33600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 33800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 34000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 34200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 34400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 34600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 34800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 35000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 35200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 35400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 35600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 35800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 36000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 36200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 36400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 36600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 36800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 37000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 37200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 37400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 37600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 37800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 38000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 38200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 38400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 38600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 38800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 39000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 39200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 39400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 39600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 39800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 40000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 40200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 40400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 40600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 40800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 41000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 41200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 41400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 41600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 41800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 42000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 42200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 42400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 42600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 42800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 43000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 43200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 43400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 43600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 43800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 44000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 44200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 44400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 44600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 44800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 45000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 45200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 45400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 45600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 45800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 46000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 46200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 46400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 46600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 46800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 47000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 47200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 47400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 47600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 47800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 48000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 48200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 48400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 48600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 48800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 49000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 49200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 49400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 49600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 49800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 50000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 50200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 50400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 50600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 50800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 51000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 51200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 51400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 51600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 51800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 52000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 52200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 52400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 52600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 52800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 53000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 53200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 53400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 53600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 53800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 54000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 54200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 54400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 54600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 54800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 55000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 55200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 55400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 55600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 55800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 56000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 56200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 56400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 56600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 56800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 57000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 57200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 57400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 57600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 57800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 58000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 58200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 58400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 58600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 58800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 59000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 59200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 59400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 59600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 59800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 60000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 60200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 60400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 60600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 60800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 61000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 61200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 61400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 61600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 61800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 62000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 62200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 62400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 62600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 62800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 63000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 63200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 63400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 63600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 63800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 64000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 64200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 64400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 64600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 64800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 65000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 65200, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 65400, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 65600, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 65800, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 66000, "reading": 4.85, "confidence": 1.0},
#   {"ts_ms": 66200, "reading": 4.85, "confidence": 1.0}
# ]
# ```
# 257.7078173160553
#
# ==================== Processing: V2_10 divisions_per_second ====================
# Uploading...
# Uploaded: files/4c46ie05ybhu
# Still processing, waiting...
# Still processing, waiting...
# Succeed
# Generatng...
# [
#   {"ts_ms": 2400, "reading": 5.97, "confidence": 0.95},
#   {"ts_ms": 2600, "reading": 6.00, "confidence": 0.95},
#   {"ts_ms": 2800, "reading": 6.03, "confidence": 0.95},
#   {"ts_ms": 3000, "reading": 6.06, "confidence": 0.95},
#   {"ts_ms": 3200, "reading": 6.09, "confidence": 0.95},
#   {"ts_ms": 3400, "reading": 6.12, "confidence": 0.95},
#   {"ts_ms": 3600, "reading": 6.15, "confidence": 0.95},
#   {"ts_ms": 3800, "reading": 6.18, "confidence": 0.95},
#   {"ts_ms": 4000, "reading": 6.21, "confidence": 0.95},
#   {"ts_ms": 4200, "reading": 6.25, "confidence": 0.95},
#   {"ts_ms": 4400, "reading": 6.28, "confidence": 0.95},
#   {"ts_ms": 4600, "reading": 6.31, "confidence": 0.95},
#   {"ts_ms": 4800, "reading": 6.34, "confidence": 0.95},
#   {"ts_ms": 5000, "reading": 6.37, "confidence": 0.95},
#   {"ts_ms": 5200, "reading": 6.40, "confidence": 0.95},
#   {"ts_ms": 5400, "reading": 6.43, "confidence": 0.95},
#   {"ts_ms": 5600, "reading": 6.46, "confidence": 0.95},
#   {"ts_ms": 5800, "reading": 6.50, "confidence": 0.95},
#   {"ts_ms": 6000, "reading": 6.53, "confidence": 0.95},
#   {"ts_ms": 6200, "reading": 6.56, "confidence": 0.95},
#   {"ts_ms": 6400, "reading": 6.59, "confidence": 0.95},
#   {"ts_ms": 6600, "reading": 6.62, "confidence": 0.95},
#   {"ts_ms": 6800, "reading": 6.65, "confidence": 0.95},
#   {"ts_ms": 7000, "reading": 6.68, "confidence": 0.95},
#   {"ts_ms": 7200, "reading": 6.71, "confidence": 0.95},
#   {"ts_ms": 25200, "reading": 9.52, "confidence": 0.95},
#   {"ts_ms": 25400, "reading": 9.56, "confidence": 0.95},
#   {"ts_ms": 25600, "reading": 9.59, "confidence": 0.95},
#   {"ts_ms": 25800, "reading": 9.62, "confidence": 0.95},
#   {"ts_ms": 26000, "reading": 9.65, "confidence": 0.95},
#   {"ts_ms": 26200, "reading": 9.68, "confidence": 0.95},
#   {"ts_ms": 26400, "reading": 9.71, "confidence": 0.95},
#   {"ts_ms": 26600, "reading": 9.74, "confidence": 0.95},
#   {"ts_ms": 26800, "reading": 9.77, "confidence": 0.95},
#   {"ts_ms": 27000, "reading": 9.81, "confidence": 0.95},
#   {"ts_ms": 27200, "reading": 9.84, "confidence": 0.95},
#   {"ts_ms": 27400, "reading": 9.87, "confidence": 0.95},
#   {"ts_ms": 27600, "reading": 9.90, "confidence": 0.95},
#   {"ts_ms": 27800, "reading": 9.93, "confidence": 0.95},
#   {"ts_ms": 28000, "reading": 9.96, "confidence": 0.95},
#   {"ts_ms": 28200, "reading": 9.99, "confidence": 0.95},
#   {"ts_ms": 28400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 28600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 28800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 29000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 29200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 29400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 29600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 29800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 30000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 30200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 30400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 30600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 30800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 31000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 31200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 31400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 31600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 31800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 32000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 32200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 32400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 32600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 32800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 33000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 33200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 33400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 33600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 33800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 34000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 34200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 34400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 34600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 34800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 35000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 35200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 35400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 35600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 35800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 36000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 36200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 36400, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 36600, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 36800, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 37000, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 37200, "reading": 10.00, "confidence": 0.95},
#   {"ts_ms": 37400, "reading": 10.00, "confidence": 0.95}
# ]
# 204.6299924850464
#
# ==================== Processing: V3_17 divisions_per_second ====================
# Uploading...
# Uploaded: files/ov7jc771p8pd
# Still processing, waiting...
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 2600, "reading": 4.92, "confidence": 0.95},
#   {"ts_ms": 2800, "reading": 4.94, "confidence": 0.95},
#   {"ts_ms": 3000, "reading": 4.96, "confidence": 0.95},
#   {"ts_ms": 3200, "reading": 4.97, "confidence": 0.95},
#   {"ts_ms": 3400, "reading": 4.99, "confidence": 0.95},
#   {"ts_ms": 3600, "reading": 5.01, "confidence": 0.95},
#   {"ts_ms": 3800, "reading": 5.03, "confidence": 0.95},
#   {"ts_ms": 4000, "reading": 5.05, "confidence": 0.95},
#   {"ts_ms": 4200, "reading": 5.07, "confidence": 0.95},
#   {"ts_ms": 4400, "reading": 5.09, "confidence": 0.95},
#   {"ts_ms": 4600, "reading": 5.11, "confidence": 0.95},
#   {"ts_ms": 4800, "reading": 5.13, "confidence": 0.95},
#   {"ts_ms": 5000, "reading": 5.15, "confidence": 0.95},
#   {"ts_ms": 5200, "reading": 5.17, "confidence": 0.95},
#   {"ts_ms": 5400, "reading": 5.19, "confidence": 0.95},
#   {"ts_ms": 5600, "reading": 5.21, "confidence": 0.95},
#   {"ts_ms": 5800, "reading": 5.23, "confidence": 0.95},
#   {"ts_ms": 23800, "reading": 6.99, "confidence": 0.95},
#   {"ts_ms": 24000, "reading": 7.01, "confidence": 0.95},
#   {"ts_ms": 24200, "reading": 7.03, "confidence": 0.95},
#   {"ts_ms": 24400, "reading": 7.05, "confidence": 0.95}
# ]
# ```
# 128.32679271697998
#
# ==================== Processing: V4_33 divisions_per_second ====================
# Uploading...
# Uploaded: files/u3x1ecrdbyxs
# Still processing, waiting...
# Succeed
# Generatng...
# [
#   {"ts_ms": 2200, "reading": 5.925, "confidence": 0.95},
#   {"ts_ms": 2400, "reading": 5.949, "confidence": 0.95},
#   {"ts_ms": 2600, "reading": 5.973, "confidence": 0.95},
#   {"ts_ms": 2800, "reading": 5.997, "confidence": 0.95},
#   {"ts_ms": 3000, "reading": 6.021, "confidence": 0.95},
#   {"ts_ms": 3200, "reading": 6.045, "confidence": 0.95},
#   {"ts_ms": 3400, "reading": 6.069, "confidence": 0.95},
#   {"ts_ms": 3600, "reading": 6.093, "confidence": 0.95},
#   {"ts_ms": 3800, "reading": 6.117, "confidence": 0.95},
#   {"ts_ms": 4000, "reading": 6.141, "confidence": 0.95},
#   {"ts_ms": 4200, "reading": 6.165, "confidence": 0.95},
#   {"ts_ms": 4400, "reading": 6.189, "confidence": 0.95},
#   {"ts_ms": 4600, "reading": 6.213, "confidence": 0.95},
#   {"ts_ms": 4800, "reading": 6.237, "confidence": 0.95},
#   {"ts_ms": 5000, "reading": 6.261, "confidence": 0.95},
#   {"ts_ms": 5200, "reading": 6.285, "confidence": 0.95},
#   {"ts_ms": 5400, "reading": 6.309, "confidence": 0.95},
#   {"ts_ms": 5600, "reading": 6.333, "confidence": 0.95},
#   {"ts_ms": 5800, "reading": 6.357, "confidence": 0.95},
#   {"ts_ms": 6000, "reading": 6.381, "confidence": 0.95},
#   {"ts_ms": 6200, "reading": 6.405, "confidence": 0.95},
#   {"ts_ms": 6400, "reading": 6.429, "confidence": 0.95},
#   {"ts_ms": 6600, "reading": 6.453, "confidence": 0.95},
#   {"ts_ms": 6800, "reading": 6.477, "confidence": 0.95},
#   {"ts_ms": 7000, "reading": 6.501, "confidence": 0.95},
#   {"ts_ms": 7200, "reading": 6.525, "confidence": 0.95},
#   {"ts_ms": 7400, "reading": 6.549, "confidence": 0.95},
#   {"ts_ms": 7600, "reading": 6.573, "confidence": 0.95},
#   {"ts_ms": 7800, "reading": 6.597, "confidence": 0.95},
#   {"ts_ms": 8000, "reading": 6.621, "confidence": 0.95},
#   {"ts_ms": 8200, "reading": 6.645, "confidence": 0.95},
#   {"ts_ms": 8400, "reading": 6.669, "confidence": 0.95},
#   {"ts_ms": 8600, "reading": 6.693, "confidence": 0.95},
#   {"ts_ms": 8800, "reading": 6.717, "confidence": 0.95},
#   {"ts_ms": 9000, "reading": 6.741, "confidence": 0.95},
#   {"ts_ms": 9200, "reading": 6.765, "confidence": 0.95},
#   {"ts_ms": 9400, "reading": 6.789, "confidence": 0.95},
#   {"ts_ms": 9600, "reading": 6.813, "confidence": 0.95},
#   {"ts_ms": 9800, "reading": 6.837, "confidence": 0.95},
#   {"ts_ms": 10000, "reading": 6.861, "confidence": 0.95},
#   {"ts_ms": 10200, "reading": 6.885, "confidence": 0.95},
#   {"ts_ms": 10400, "reading": 6.909, "confidence": 0.95},
#   {"ts_ms": 10600, "reading": 6.933, "confidence": 0.95},
#   {"ts_ms": 10800, "reading": 6.957, "confidence": 0.95},
#   {"ts_ms": 11000, "reading": 6.981, "confidence": 0.95},
#   {"ts_ms": 11200, "reading": 7.005, "confidence": 0.95},
#   {"ts_ms": 11400, "reading": 7.029, "confidence": 0.95},
#   {"ts_ms": 11600, "reading": 7.053, "confidence": 0.95},
#   {"ts_ms": 11800, "reading": 7.077, "confidence": 0.95},
#   {"ts_ms": 12000, "reading": 7.101, "confidence": 0.95},
#   {"ts_ms": 12200, "reading": 7.125, "confidence": 0.95},
#   {"ts_ms": 12400, "reading": 7.149, "confidence": 0.95},
#   {"ts_ms": 12600, "reading": 7.173, "confidence": 0.95},
#   {"ts_ms": 12800, "reading": 7.197, "confidence": 0.95},
#   {"ts_ms": 13000, "reading": 7.221, "confidence": 0.95},
#   {"ts_ms": 13200, "reading": 7.245, "confidence": 0.95},
#   {"ts_ms": 13400, "reading": 7.269, "confidence": 0.95},
#   {"ts_ms": 13600, "reading": 7.293, "confidence": 0.95},
#   {"ts_ms": 13800, "reading": 7.317, "confidence": 0.95},
#   {"ts_ms": 14000, "reading": 7.341, "confidence": 0.95},
#   {"ts_ms": 14200, "reading": 7.365, "confidence": 0.95},
#   {"ts_ms": 14400, "reading": 7.389, "confidence": 0.95},
#   {"ts_ms": 14600, "reading": 7.413, "confidence": 0.95},
#   {"ts_ms": 14800, "reading": 7.437, "confidence": 0.95},
#   {"ts_ms": 15000, "reading": 7.461, "confidence": 0.95}
# ]
# 130.96119141578674
#
# ==================== Processing: V5_50 divisions_per_second ====================
# Uploading...
# Uploaded: files/zyyodo4xg0lb
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 2200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 5.0, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 5.0, "confidence": 1.0}
# ]
# ```
# 79.5744047164917
#
# ==================== Processing: V6_100 divisions_per_second ====================
# Uploading...
# Uploaded: files/p3fjxjjdl3tl
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 3000, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 3200, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 3400, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 3600, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 3800, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 4000, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 4200, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 4400, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 4600, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 4800, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 5000, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 5200, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 5400, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 5600, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 5800, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 6000, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 6200, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 6400, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 6600, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 6800, "reading": 5.88, "confidence": 0.98},
#   {"ts_ms": 7000, "reading": 5.88, "confidence": 0.95},
#   {"ts_ms": 7200, "reading": 5.87, "confidence": 0.95},
#   {"ts_ms": 7400, "reading": 5.86, "confidence": 0.95},
#   {"ts_ms": 7600, "reading": 5.84, "confidence": 0.95},
#   {"ts_ms": 7800, "reading": 5.83, "confidence": 0.95},
#   {"ts_ms": 8000, "reading": 5.82, "confidence": 0.95},
#   {"ts_ms": 8200, "reading": 5.81, "confidence": 0.95},
#   {"ts_ms": 8400, "reading": 5.80, "confidence": 0.95},
#   {"ts_ms": 8600, "reading": 5.78, "confidence": 0.95},
#   {"ts_ms": 8800, "reading": 5.77, "confidence": 0.95},
#   {"ts_ms": 9000, "reading": 5.76, "confidence": 0.95},
#   {"ts_ms": 9200, "reading": 5.75, "confidence": 0.95},
#   {"ts_ms": 9400, "reading": 5.74, "confidence": 0.95},
#   {"ts_ms": 9600, "reading": 5.72, "confidence": 0.95},
#   {"ts_ms": 9800, "reading": 5.71, "confidence": 0.95},
#   {"ts_ms": 10000, "reading": 5.70, "confidence": 0.95},
#   {"ts_ms": 10200, "reading": 5.69, "confidence": 0.95},
#   {"ts_ms": 10400, "reading": 5.68, "confidence": 0.95},
#   {"ts_ms": 10600, "reading": 5.66, "confidence": 0.95},
#   {"ts_ms": 10800, "reading": 5.65, "confidence": 0.95},
#   {"ts_ms": 11000, "reading": 5.64, "confidence": 0.95},
#   {"ts_ms": 11200, "reading": 5.63, "confidence": 0.95},
#   {"ts_ms": 11400, "reading": 5.62, "confidence": 0.95},
#   {"ts_ms": 11600, "reading": 5.60, "confidence": 0.95},
#   {"ts_ms": 11800, "reading": 5.59, "confidence": 0.95},
#   {"ts_ms": 12000, "reading": 5.58, "confidence": 0.95}
# ]
# ```
# 97.83398175239563

# %%
# test single frame
import time
import os
from google import genai
import pandas as pd
from google.genai import types
file_path = 'Dataset/1_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]
# output_dir = 'Results/1.- Analog Dial Gauge'
# os.makedirs(output_dir, exist_ok=True)
target_timestamps = [9200]
video_files = ['V3_17 divisions_per_second.mp4']

for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    
    
    print(f"\n{'='*20} processing: {seq_id} {'='*20}")

    program_start_time = time.time()
    myfile = client.files.upload(file=f"Dataset/1.- Analog Dial Gauge/{seq_id}.mp4")


    while True:
        file_status = client.files.get(name=myfile.name)

        if file_status.state == "ACTIVE":
            break
        elif file_status.state == "FAILED":
            raise Exception("failed (State: FAILED)")

        print("waiting...")
        time.sleep(5)
    # -----------------------------

    # message = "Sample the video every 5 seconds. At each step, identify the time on the digital clock and detect ALL visible analog gauges. Read each gauge and present the data in a table with columns: [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading]"
    # message = 'Read each gauge every 5 seconds and present the data in a table with columns: [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading] where reading marks if the value increases as + or decreases as -'

    # message = '''Read each gauge every 5 seconds and present the data in a table with columns:
    # [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading],
    # where Reading indicates whether the gauge value increases (+) or decreases (−) in the video.'''

    message = f'''
ROLE: Expert Industrial Metrology Assistant
PROTOCOL: See-Think-Confirm
1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "stc_analysis": string, "reading": float, "conf": float}}
TASK: Extract a high-precision time-series of readings from the video.


INSTRUMENT METADATA:
- Gauge Type: {gauge_type} | Unit: {unit}

SAMPLING PROTOCOL:
- Target Timestamps (ts_ms): {target_timestamps}
- Requirement: For each timestamp in the list, locate the frame where the in-band digital chronometer matches this value.

RESPONSE REQUIREMENT:
Output a single JSON array where each entry contains: {{"ts_ms": integer, "stc_analysis": "SEE: ... | THINK: ... | CONFIRM: ...", "reading": float, "confidence": float}}
'''
    
#     model_name = "gemini-3-flash-preview"
#     model_name = "gemini-3-pro-preview"
    model_name = "gemini-3.1-pro-preview"
    response = client.models.generate_content(
        model=model_name, 
        contents=[myfile, message],
        config=types.GenerateContentConfig(
            temperature=0.0,  
            thinking_config=types.ThinkingConfig(thinking_level="high", include_thoughts=True)
        )
        
    )
    # "Identify the analog gauge and output a timestamped table of its readings based on the visible dial markings."
    print(response.text)
    
    for part in response.candidates[0].content.parts:
        if part and part.thought:  # show thoughts
            print(part.text)
        
    program_end_time = time.time()
    total_duration = program_end_time - program_start_time
    print(total_duration)
# Out:
# ==================== processing: V3_17 divisions_per_second ====================
# waiting...
# waiting...
# ```json
# [
#   {
#     "ts_ms": 9200,
#     "stc_analysis": "SEE: Large dial needle is between 80 and 90. Small dial needle is between 0 and 1. | THINK: Small dial indicates 0mm. Large dial is at 84, which means 0.84mm. Total reading is 0.84mm. | CONFIRM: Reading is 0.84mm, consistent with the counter-clockwise movement.",
#     "reading": 0.84,
#     "conf": 0.95
#   }
# ]
# ```
# **Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.
#
#
#
# 43.32640624046326

# %%
response.candidates[0].content
# Out:
# Content(
#   parts=[
#     Part(
#       text="""**Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.
#
#
# """,
#       thought=True
#     ),
#     Part(
#       text="""```json
# [
#   {
#     "ts_ms": 9200,
#     "stc_analysis": "SEE: Large dial needle is between 80 and 90. Small dial needle is between 0 and 1. | THINK: Small dial indicates 0mm. Large dial is at 84, which means 0.84mm. Total reading is 0.84mm. | CONFIRM: Reading is 0.84mm, consistent with the counter-clockwise movement.",
#     "reading": 0.84,
#     "conf": 0.95
#   }
# ]
# ```""",
#       thought_signature=b'\x12\xca\x10\n\xc7\x10\x01\xbe>\xf6\xfb\xe8\x92\xc6\x9b\xbc\xd9\x93\x10\x08\x14Ho\xfe\xf1\xa0o\xa9\xa6E~\x19\x19V\xd0-\x82\xe5\xe1\x84\xe8\xf5\xa5\x15\xce\x16]\xdc\x02\xce\x80HC2\x886\xc5\xde\x13\xf8\xe64\xed\xc7\xe2\x88t\x1a\xf9\xfa\xc78:\xceC[k\xbcx\x02f\x9bd\xe6O?6\xcd\x888M\x9b\xcf\x94\xc3cQ...'
#     ),
#   ],
#   role='model'
# )

# %%
content_parts = response.candidates[0].content.parts
thinking_process = content_parts[0].text if len(content_parts) > 0 else ""
print(thinking_process)
# Out:
# **Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.

# %%
import time
import os
import pandas as pd
file_path = 'Dataset/3_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
graduation_interval = df.loc['graduation_interval', 'Content / Example']



VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]

    
for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    
    
    print(f"\n{'='*20} Processing: {seq_id} {'='*20}")

    print("Uploading...")
    program_start_time = time.time()


        
# # CoT prompt
#     message = f'''
#     ROLE: Expert Industrial Metrology Assistant

#     PROTOCOL: See-Think-Confirm
#     1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
#     2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
#     3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
#     CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     TASK: Extract a high-precision time-series of readings from the video.

#     INSTRUMENT METADATA:
#     - Gauge Type:{gauge_type} | Unit: {unit} 
#     - Graduation Interval: {graduation_interval}
#     - Calibrated Range: [{reading_start}, {reading_end}]

#     SAMPLING PROTOCOL:
#     - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
#     - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
#     - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
#     - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

#     RESPONSE REQUIREMENT:
#     Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     '''
# naive prompt
    message = f'''
    ROLE: Expert Industrial Metrology Assistant

    TASK: Read the analog gauge values from the video at specific time intervals.

    INSTRUMENT METADATA:
    - Gauge Type:{gauge_type} | Unit: {unit} 
    - Graduation Interval: {graduation_interval}
    - Calibrated Range: [{reading_start}, {reading_end}]

    SAMPLING REQUIREMENTS:
    - Use the digital chronometer shown in the video for timing.
    - Start reading from the first 200ms integer increment.
    - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
    - Continue until the video ends.

    OUTPUT FORMAT:
    Return only a JSON array of objects: {{"ts_ms": integer, "reading": float, "confidence": float}}
    '''
    print(message)
    break
# Out:
# ==================== Processing: V1_5 divisions_per_second ====================
# Uploading...
#
#     ROLE: Expert Industrial Metrology Assistant
#
#     TASK: Read the analog gauge values from the video at specific time intervals.
#
#     INSTRUMENT METADATA:
#     - Gauge Type:Caliper | Unit: mm
#     - Graduation Interval: 1
#     - Calibrated Range: [0.0, 50.0]
#
#     SAMPLING REQUIREMENTS:
#     - Use the digital chronometer shown in the video for timing.
#     - Start reading from the first 200ms integer increment.
#     - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
#     - Continue until the video ends.
#
#     OUTPUT FORMAT:
#     Return only a JSON array of objects: {"ts_ms": integer, "reading": float, "confidence": float}

# %%
#     ROLE: Expert Industrial Metrology Assistant

#     PROTOCOL: See-Think-Confirm
#     1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
#     2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
#     3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
#     CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     TASK: Extract a high-precision time-series of readings from the video.

#     INSTRUMENT METADATA:
#     - Gauge Type:Circular | Unit: mm
#     - Graduation Interval: 0.01
#     - Calibrated Range: [0, 10]

#     SAMPLING PROTOCOL:
#     - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
#     - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
#     - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
#     - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

#     RESPONSE REQUIREMENT:
#     Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}

# %%
# message = f'''
# ROLE: Expert Industrial Metrology Assistant.

# PROTOCOL: See-Think-Confirm (apply internally; output JSON only as specified below).

# 1. SEE
#    - Locate the analog gauge and its scale boundaries. Treat the scale minimum as [0%] and scale maximum as [100%] (these correspond to Calibrated Range below).
#    - Identify the digital chronometer in the frame and read its displayed time in milliseconds.
#    - Note needle position relative to tick marks; if the needle is between two marks, estimate by subdivision (use Graduation Interval).

# 2. THINK
#    - Map each required timestamp (ts_ms) to the correct moment in the video using the in-band digital chronometer as the sole time reference.
#    - If no frame shows the chronometer exactly at ts_ms: pick the nearest frame(s) and linearly interpolate the reading from adjacent chronometer values and needle positions (ΔReading/ΔTime). Maintain temporal continuity: each new reading should be consistent with the previous reading and the direction of motion (clockwise or counter-clockwise).
#    - Optionally use thought signatures or internal state to carry last_ts_ms, last_reading, and trend across frames.

# 3. CONFIRM
#    - Clamp every reading to the Calibrated Range [min, max].
#    - Enforce physical monotonicity: readings should not reverse direction unless the needle visibly reverses in the video. Small jitter from parallax or blur may be smoothed; if unsure, reflect it in confidence.
#    - Set confidence (0.0–1.0) by: visibility of scale and needle, alignment of chronometer with ts_ms, and consistency with neighboring readings. Lower confidence if interpolating heavily or if the gauge is partially occluded.

# CONSTRAINT: Output a single JSON array only. No markdown, no explanation outside the array. Each element: {{"ts_ms": integer, "reading": float, "confidence": float}}.

# TASK: Produce a high-precision time-series of gauge readings from the video at the specified sampling instants.

# INSTRUMENT METADATA:
# - Gauge Type: {gauge_type} | Unit: {unit}
# - Graduation Interval: {graduation_interval}
# - Calibrated Range: [{reading_start}, {reading_end}]

# SAMPLING PROTOCOL:
# - Time reference: Every output ts_ms must align with the digital chronometer value (in ms) visible in the video. Use the chronometer as the ground truth for time; ignore video file timestamps.
# - Start: Begin from the first 200 ms integer multiple reached by the chronometer (e.g. if it starts at 5670 ms, first output entry at 5800 ms). Omit any earlier frames.
# - Interval: One reading every 200 ms by chronometer (e.g. 5800, 6000, 6200, …).
# - End: Continue until the video ends, always using chronometer values for ts_ms.

# RESPONSE REQUIREMENT:
# Output only one JSON array. Each entry: {{"ts_ms": integer, "reading": float, "confidence": float}}. No other text before or after.
# '''
