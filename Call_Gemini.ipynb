# %%
import time
import os
from google import genai
import pandas as pd
from google.genai import types
file_path = 'Dataset/1_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
graduation_interval = df.loc['graduation_interval', 'Content / Example']

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])
model_name = "gemini-3-flash-preview"
# model_name = "gemini-3-pro-preview"


VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]
output_dir = f'Results_new_0303/1.- Analog Dial Gauge_{model_name}'
os.makedirs(output_dir, exist_ok=True)
    
for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    
    output_file = os.path.join(output_dir, f'{seq_id}_Raw_Results.xlsx')
    if os.path.exists(output_file):
        print(f"Skipping: {seq_id} (the result file already exists)")
        continue
    
    print(f"\n{'='*20} Processing: {seq_id} {'='*20}")

    print("Uploading...")
    program_start_time = time.time()
    myfile = client.files.upload(file=f"Dataset/1.- Analog Dial Gauge/{seq_id}.mp4")
    print(f"Uploaded: {myfile.name}")

    while True:
        file_status = client.files.get(name=myfile.name)

        if file_status.state == "ACTIVE":
            print("Succeed")
            break
        elif file_status.state == "FAILED":
            raise Exception("Failed (State: FAILED)")

        print("Still processing, waiting...")
        time.sleep(5)

        
# CoT prompt
    message = f'''
    ROLE: Expert Industrial Metrology Assistant

    PROTOCOL: See-Think-Confirm
    1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
    2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
    3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
    CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
    TASK: Extract a high-precision time-series of readings from the video.

    INSTRUMENT METADATA:
    - Gauge Type:{gauge_type} | Unit: {unit} 
    - Graduation Interval: {graduation_interval}
    - Calibrated Range: [{reading_start}, {reading_end}]

    SAMPLING PROTOCOL:
    - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
    - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
    - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
    - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

    RESPONSE REQUIREMENT:
    Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}
    '''

# naive prompt
#     message = f'''
#     ROLE: Expert Industrial Metrology Assistant

#     TASK: Read the analog gauge values from the video at specific time intervals.

#     INSTRUMENT METADATA:
#     - Gauge Type:{gauge_type} | Unit: {unit} 
#     - Graduation Interval: {graduation_interval}
#     - Calibrated Range: [{reading_start}, {reading_end}]

#     SAMPLING REQUIREMENTS:
#     - Use the digital chronometer shown in the video for timing.
#     - Start reading from the first 200ms integer increment.
#     - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
#     - Continue until the video ends.

#     OUTPUT FORMAT:
#     Return only a JSON array of objects: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     '''
    print("Generatng...")

    response = client.models.generate_content(
        model=model_name, 
        contents=[myfile, message],
        config=types.GenerateContentConfig(
            temperature=0.0,
            thinking_config=types.ThinkingConfig(thinking_level="high")
        )
    )
    # "Identify the analog gauge and output a timestamped table of its readings based on the visible dial markings."
    print(response.text)


    program_end_time = time.time()
    total_duration = program_end_time - program_start_time
    print(total_duration)

    df_output = pd.DataFrame([{
        "sequence_id": seq_id,
        "raw_model_response": response.text,
        "total_duration_sec": round(total_duration, 2),
        "model_name": model_name,
    }])

    df_output.to_excel(output_file, index=False)
# Out:
# ==================== Processing: V1_5 divisions_per_second ====================
# Uploading...
# Uploaded: files/fuslawuzuk8y
# Still processing, waiting...
# Still processing, waiting...
# Still processing, waiting...
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 0, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 200, "reading": 0.0014, "confidence": 1.0},
#   {"ts_ms": 400, "reading": 0.0028, "confidence": 1.0},
#   {"ts_ms": 600, "reading": 0.0042, "confidence": 1.0},
#   {"ts_ms": 800, "reading": 0.0056, "confidence": 1.0},
#   {"ts_ms": 1000, "reading": 0.007, "confidence": 1.0},
#   {"ts_ms": 1200, "reading": 0.0084, "confidence": 1.0},
#   {"ts_ms": 1400, "reading": 0.0098, "confidence": 1.0},
#   {"ts_ms": 1600, "reading": 0.0112, "confidence": 1.0},
#   {"ts_ms": 1800, "reading": 0.0126, "confidence": 1.0},
#   {"ts_ms": 2000, "reading": 0.014, "confidence": 1.0},
#   {"ts_ms": 2200, "reading": 0.0154, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 0.0168, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 0.0182, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 0.0196, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 0.021, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 0.0224, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 0.0238, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 0.0252, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 0.0266, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 0.028, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 0.0294, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 0.0308, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 0.0322, "confidence": 1.0},
#   {"ts_ms": 66000, "reading": 0.462, "confidence": 1.0},
#   {"ts_ms": 66200, "reading": 0.4634, "confidence": 1.0}
# ]
# ```
# 109.68144536018372
#
# ==================== Processing: V2_10 divisions_per_second ====================
# Uploading...
# Uploaded: files/zxe1sangn7bo
# Still processing, waiting...
# Still processing, waiting...
# Succeed
# Generatng...
# ```json
# [
#   {"ts_ms": 2400, "reading": 0.00009, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 0.00069, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 0.00129, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 0.00189, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 0.00249, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 0.00309, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 0.00369, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 0.00429, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 0.00488, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 0.00548, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 0.00608, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 0.00668, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 0.00728, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 0.00788, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 0.00848, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 0.00908, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 0.00968, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 0.01028, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 0.01088, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 0.01148, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 0.01208, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 0.01268, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 0.01327, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 0.01387, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 0.01447, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 0.01507, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 0.01567, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 0.01627, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 0.01687, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 0.01747, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 0.01807, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 0.01867, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 0.01927, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 0.01987, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 0.02047, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 0.02107, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 0.02167, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 0.02226, "confidence": 1.0},
#   {"ts_ms": 14400, "reading": 0.612, "confidence": 1.0},
#   {"ts_ms": 14600, "reading": 0.622, "confidence": 1.0},
#   {"ts_ms": 14800, "reading": 0.632, "confidence": 1.0},
#   {"ts_ms": 15000, "reading": 0.641, "confidence": 1.0}
# ]
# ```
# 61.78890514373779
#
# ==================== Processing: V5_50 divisions_per_second ====================
# Uploading...
# Uploaded: files/ge86pyx4eccn
# Still processing, waiting...
# Succeed
# Generatng...
# [
#   {"ts_ms": 0, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 200, "reading": 0.02, "confidence": 1.0},
#   {"ts_ms": 400, "reading": 0.04, "confidence": 1.0},
#   {"ts_ms": 600, "reading": 0.06, "confidence": 1.0},
#   {"ts_ms": 800, "reading": 0.08, "confidence": 1.0},
#   {"ts_ms": 1000, "reading": 0.1, "confidence": 1.0},
#   {"ts_ms": 1200, "reading": 0.12, "confidence": 1.0},
#   {"ts_ms": 1400, "reading": 0.14, "confidence": 1.0},
#   {"ts_ms": 1600, "reading": 0.16, "confidence": 1.0},
#   {"ts_ms": 1800, "reading": 0.18, "confidence": 1.0},
#   {"ts_ms": 2000, "reading": 0.2, "confidence": 1.0},
#   {"ts_ms": 2200, "reading": 0.22, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 0.24, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 0.26, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 0.28, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 0.3, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 0.32, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 0.34, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 0.36, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 0.38, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 0.4, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 0.42, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 0.44, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 0.46, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 0.48, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 0.5, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 0.52, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 0.54, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 0.56, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 0.58, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 0.6, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 0.62, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 0.64, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 0.66, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 0.68, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 0.7, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 0.72, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 0.74, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 0.76, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 0.78, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 0.8, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 0.82, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 0.84, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 0.86, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 0.88, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 0.9, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 0.92, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 0.94, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 0.96, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 0.98, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 1.0, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 1.02, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 1.04, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 1.06, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 1.08, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 1.1, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 1.12, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 1.14, "confidence": 1.0}
# ]
# 40.66938900947571
#
# ==================== Processing: V6_100 divisions_per_second ====================
# Uploading...
# Uploaded: files/ifre04xwjwp6
# Still processing, waiting...
# Succeed
# Generatng...
# [
#   {"ts_ms": 3000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 4.755, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 4.755, "confidence": 1.0}
# ]
# 53.54827857017517

# %%
# test single frame
import time
import os
from google import genai
import pandas as pd
from google.genai import types
file_path = 'Dataset/1_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]
# output_dir = 'Results/1.- Analog Dial Gauge'
# os.makedirs(output_dir, exist_ok=True)
target_timestamps = [9200]
video_files = ['V3_17 divisions_per_second.mp4']

for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    
    
    print(f"\n{'='*20} processing: {seq_id} {'='*20}")

    program_start_time = time.time()
    myfile = client.files.upload(file=f"Dataset/1.- Analog Dial Gauge/{seq_id}.mp4")


    while True:
        file_status = client.files.get(name=myfile.name)

        if file_status.state == "ACTIVE":
            break
        elif file_status.state == "FAILED":
            raise Exception("failed (State: FAILED)")

        print("waiting...")
        time.sleep(5)
    # -----------------------------

    # message = "Sample the video every 5 seconds. At each step, identify the time on the digital clock and detect ALL visible analog gauges. Read each gauge and present the data in a table with columns: [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading]"
    # message = 'Read each gauge every 5 seconds and present the data in a table with columns: [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading] where reading marks if the value increases as + or decreases as -'

    # message = '''Read each gauge every 5 seconds and present the data in a table with columns:
    # [Timestamp, Digital Clock Time, Gauge Description, Inferred Scale, Reading],
    # where Reading indicates whether the gauge value increases (+) or decreases (−) in the video.'''

    message = f'''
ROLE: Expert Industrial Metrology Assistant
PROTOCOL: See-Think-Confirm
1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "stc_analysis": string, "reading": float, "conf": float}}
TASK: Extract a high-precision time-series of readings from the video.


INSTRUMENT METADATA:
- Gauge Type: {gauge_type} | Unit: {unit}

SAMPLING PROTOCOL:
- Target Timestamps (ts_ms): {target_timestamps}
- Requirement: For each timestamp in the list, locate the frame where the in-band digital chronometer matches this value.

RESPONSE REQUIREMENT:
Output a single JSON array where each entry contains: {{"ts_ms": integer, "stc_analysis": "SEE: ... | THINK: ... | CONFIRM: ...", "reading": float, "confidence": float}}
'''
    
#     model_name = "gemini-3-flash-preview"
#     model_name = "gemini-3-pro-preview"
    model_name = "gemini-3.1-pro-preview"
    response = client.models.generate_content(
        model=model_name, 
        contents=[myfile, message],
        config=types.GenerateContentConfig(
            temperature=0.0,  
            thinking_config=types.ThinkingConfig(thinking_level="high", include_thoughts=True)
        )
        
    )
    # "Identify the analog gauge and output a timestamped table of its readings based on the visible dial markings."
    print(response.text)
    
    for part in response.candidates[0].content.parts:
        if part and part.thought:  # show thoughts
            print(part.text)
        
    program_end_time = time.time()
    total_duration = program_end_time - program_start_time
    print(total_duration)
# Out:
# ==================== processing: V3_17 divisions_per_second ====================
# waiting...
# waiting...
# ```json
# [
#   {
#     "ts_ms": 9200,
#     "stc_analysis": "SEE: Large dial needle is between 80 and 90. Small dial needle is between 0 and 1. | THINK: Small dial indicates 0mm. Large dial is at 84, which means 0.84mm. Total reading is 0.84mm. | CONFIRM: Reading is 0.84mm, consistent with the counter-clockwise movement.",
#     "reading": 0.84,
#     "conf": 0.95
#   }
# ]
# ```
# **Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.
#
#
#
# 43.32640624046326

# %%
response.candidates[0].content
# Out:
# Content(
#   parts=[
#     Part(
#       text="""**Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.
#
#
# """,
#       thought=True
#     ),
#     Part(
#       text="""```json
# [
#   {
#     "ts_ms": 9200,
#     "stc_analysis": "SEE: Large dial needle is between 80 and 90. Small dial needle is between 0 and 1. | THINK: Small dial indicates 0mm. Large dial is at 84, which means 0.84mm. Total reading is 0.84mm. | CONFIRM: Reading is 0.84mm, consistent with the counter-clockwise movement.",
#     "reading": 0.84,
#     "conf": 0.95
#   }
# ]
# ```""",
#       thought_signature=b'\x12\xca\x10\n\xc7\x10\x01\xbe>\xf6\xfb\xe8\x92\xc6\x9b\xbc\xd9\x93\x10\x08\x14Ho\xfe\xf1\xa0o\xa9\xa6E~\x19\x19V\xd0-\x82\xe5\xe1\x84\xe8\xf5\xa5\x15\xce\x16]\xdc\x02\xce\x80HC2\x886\xc5\xde\x13\xf8\xe64\xed\xc7\xe2\x88t\x1a\xf9\xfa\xc78:\xceC[k\xbcx\x02f\x9bd\xe6O?6\xcd\x888M\x9b\xcf\x94\xc3cQ...'
#     ),
#   ],
#   role='model'
# )

# %%
content_parts = response.candidates[0].content.parts
thinking_process = content_parts[0].text if len(content_parts) > 0 else ""
print(thinking_process)
# Out:
# **Dial Gauge Reading at Timestamp 9200 ms**
#
# Okay, so the task is to pinpoint a reading from a dial gauge at exactly 9200 milliseconds, or 00:09.20 on the chronometer. First, I need to find the frame corresponding to that specific time. Looking at the video data, I quickly locate the frame. The chronometer reads 00:09.20 at 9.2 seconds, which is what I'm after.
#
# Now, let's analyze the dial gauge itself. I visually break it down: a large dial and a small one. The large dial, with its 0 to 100 scale, and major ticks at intervals of 10, clearly represents the fractional component of the measurement. Each minor tick is 0.01mm, so a full revolution is 1mm. The small dial indicates the whole number of millimeters, with each major tick representing 1mm and a range of 0 to 10.
#
# At the target frame, my thought process goes like this: The small dial needle is clearly between 0 and 1, but close to zero, so the whole number part is definitely 0. Next, I look at the large dial. The needle is precisely between 80 and 90. Counting the minor ticks, it's right on the 4th tick past 80. So that is 84 on the large dial. Multiplying 84 by the 0.01mm per tick, I get 0.84 mm. Therefore, I can confirm the reading as 0.84 mm.
#
# I mentally cross-check: the needle's movement is counter-clockwise, which implies that the value is increasing over time, consistent with the fact that in previous frames the reading was lower. This confirms the observed reading as correct.
#
# Finally, I format the data as requested in the JSON format: a timestamp of 9200, a structured textual analysis summarizing what I observed, thought, and confirmed, the reading as 0.84, and a confidence level of 0.95. I double-check my calculation and data.
#
# The analysis is complete, and the reading is 0.84 mm at 00:09.20.

# %%
import time
import os
import pandas as pd
file_path = 'Dataset/1_label/V1_5 divisions_per_second.xlsx'
sheet_name = 'Metadata'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.set_index('Column (Header)', inplace=True)

gauge_type = df.loc['type', 'Content / Example']
unit = df.loc['unit', 'Content / Example']
reading_start = df.loc['manufacturer_range_min', 'Content / Example']
reading_end = df.loc['manufacturer_range_max', 'Content / Example']

reading_start = float(reading_start)
reading_end = float(reading_end)
graduation_interval = df.loc['graduation_interval', 'Content / Example']



VIDEO_DIR = 'Dataset/1.- Analog Dial Gauge/'
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith('.mp4')]

    
for video_filename in video_files:
    seq_id = os.path.splitext(video_filename)[0]
    

    program_start_time = time.time()


        
# # CoT prompt
#     message = f'''
#     ROLE: Expert Industrial Metrology Assistant

#     PROTOCOL: See-Think-Confirm
#     1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
#     2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
#     3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
#     CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     TASK: Extract a high-precision time-series of readings from the video.

#     INSTRUMENT METADATA:
#     - Gauge Type:{gauge_type} | Unit: {unit} 
#     - Graduation Interval: {graduation_interval}
#     - Calibrated Range: [{reading_start}, {reading_end}]

#     SAMPLING PROTOCOL:
#     - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
#     - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
#     - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
#     - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

#     RESPONSE REQUIREMENT:
#     Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     '''
## naive prompt
#     message = f'''
#     ROLE: Expert Industrial Metrology Assistant

#     TASK: Read the analog gauge values from the video at specific time intervals.

#     INSTRUMENT METADATA:
#     - Gauge Type:{gauge_type} | Unit: {unit} 
#     - Graduation Interval: {graduation_interval}
#     - Calibrated Range: [{reading_start}, {reading_end}]

#     SAMPLING REQUIREMENTS:
#     - Use the digital chronometer shown in the video for timing.
#     - Start reading from the first 200ms integer increment.
#     - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
#     - Continue until the video ends.

#     OUTPUT FORMAT:
#     Return only a JSON array of objects: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     '''
    
    
    message = f'''ROLE: Expert Industrial Metrology Assistant

GOAL:
Extract a high-precision time-series from a video of an industrial analog gauge with an in-frame digital chronometer.

OUTPUT CONSTRAINT (STRICT):
Return JSON ONLY, a single JSON array:
[
  {{"ts_ms": integer, "reading": float, "confidence": float}},
  ...
]
No extra keys, no prose.

INSTRUMENT METADATA:
- Gauge Type: {gauge_type} | Unit: {unit}
- Graduation Interval: {graduation_interval}
- Calibrated Range: [{reading_start}, {reading_end}]

SINGLE-STAGE EXECUTION PLAN (MUST FOLLOW IN ORDER):

PHASE 1 — CALIBRATION (DO ONCE, THEN LOCK REGIONS):
1) Locate the analog gauge and the digital chronometer.
   Internally determine and lock:
   - gauge_box = [ymin,xmin,ymax,xmax]
   - timer_box = [ymin,xmin,ymax,xmax]
2) Inside gauge_box, estimate:
   - gauge_center (needle pivot)
   - min_marker position corresponding to reading_start
   - max_marker position corresponding to reading_end
   - rotation direction (CW/CCW increasing)
3) Assume linear mapping from needle angle to reading unless obvious nonlinearity is visible.
4) After this phase, DO NOT re-detect boxes each time. Track within locked regions.

PHASE 2 — TIME ALIGNMENT (TIMER-DRIVEN SAMPLING):
1) For each frame, read the digital chronometer value within timer_box as an integer ts_ms.
2) Determine the first output timestamp:
   - Let ts0 be the first clearly readable timer value in the video.
   - Let t_first = the smallest multiple of 200 that is >= ts0 (round up to next 200ms).
   Example: ts0=5670 -> t_first=5800.
3) Target sequence: t_first, t_first+200, t_first+400, ... until the video ends.
4) Emit exactly ONE data point for EVERY target ts_ms (no gaps):
   - If a frame shows the timer EXACTLY equal to the target ts_ms, output a DIRECT sample from that same frame.
   - Otherwise output an INTERPOLATED sample computed from neighboring DIRECT samples.
   
PHASE 3 — READING EXTRACTION (SAME FRAME AS TIMER MATCH):
For the selected frame at each target ts_ms:
1) Detect needle direction as a ray from gauge_center to the needle tip (or farthest visible needle point).
2) Compute the needle angle relative to the min_marker and max_marker angles.
3) Map angle -> reading using linear interpolation between [reading_start, reading_end].
4) Clamp reading into [{reading_start}, {reading_end}].
5) Output reading as float.

VALIDATION & CONFIDENCE (DO NOT EDIT TS_MS):
- Do NOT enforce monotonicity by changing readings.
- Use physical plausibility only to set confidence:
  * Large abrupt jumps inconsistent with the last 5 samples -> lower confidence.
  * Timer ambiguity (glare/blur/partial digits) -> lower confidence.
  * Needle occlusion / unclear tip / reflections / parallax -> lower confidence.
- Confidence in [0,1]. Start at 1.0 and subtract penalties:
  - timer uncertain: -0.3
  - needle tip ambiguous: -0.2
  - heavy glare/occlusion: -0.2
  - calibration markers uncertain: -0.2
  (Cap at [0,1].)

IMPORTANT DETAILS:
- For DIRECT samples: read BOTH timer and needle from the SAME frame.
- For INTERPOLATED samples: ts_ms has no exact-matching frame; compute reading from neighboring DIRECT samples (do not read needle for that ts_ms).
- Only use information inside locked gauge_box and timer_box after calibration.
- Always follow the timer values in-frame; ignore video file elapsed time.

RETURN ONLY THE JSON ARRAY.
    '''
    print(message)
    break
# Out:
# ==================== Processing: V1_5 divisions_per_second ====================
# Uploading...
#
#     ROLE: Expert Industrial Metrology Assistant
#
#     TASK: Read the analog gauge values from the video at specific time intervals.
#
#     INSTRUMENT METADATA:
#     - Gauge Type:Caliper | Unit: mm
#     - Graduation Interval: 1
#     - Calibrated Range: [0.0, 50.0]
#
#     SAMPLING REQUIREMENTS:
#     - Use the digital chronometer shown in the video for timing.
#     - Start reading from the first 200ms integer increment.
#     - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
#     - Continue until the video ends.
#
#     OUTPUT FORMAT:
#     Return only a JSON array of objects: {"ts_ms": integer, "reading": float, "confidence": float}

# %%
#     ROLE: Expert Industrial Metrology Assistant

#     PROTOCOL: See-Think-Confirm
#     1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
#     2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
#     3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
#     CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
#     TASK: Extract a high-precision time-series of readings from the video.

#     INSTRUMENT METADATA:
#     - Gauge Type:Circular | Unit: mm
#     - Graduation Interval: 0.01
#     - Calibrated Range: [0, 10]

#     SAMPLING PROTOCOL:
#     - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
#     - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
#     - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...). 
#     - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

#     RESPONSE REQUIREMENT:
#     Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}

# %%
# message = f'''
# ROLE: Expert Industrial Metrology Assistant.

# PROTOCOL: See-Think-Confirm (apply internally; output JSON only as specified below).

# 1. SEE
#    - Locate the analog gauge and its scale boundaries. Treat the scale minimum as [0%] and scale maximum as [100%] (these correspond to Calibrated Range below).
#    - Identify the digital chronometer in the frame and read its displayed time in milliseconds.
#    - Note needle position relative to tick marks; if the needle is between two marks, estimate by subdivision (use Graduation Interval).

# 2. THINK
#    - Map each required timestamp (ts_ms) to the correct moment in the video using the in-band digital chronometer as the sole time reference.
#    - If no frame shows the chronometer exactly at ts_ms: pick the nearest frame(s) and linearly interpolate the reading from adjacent chronometer values and needle positions (ΔReading/ΔTime). Maintain temporal continuity: each new reading should be consistent with the previous reading and the direction of motion (clockwise or counter-clockwise).
#    - Optionally use thought signatures or internal state to carry last_ts_ms, last_reading, and trend across frames.

# 3. CONFIRM
#    - Clamp every reading to the Calibrated Range [min, max].
#    - Enforce physical monotonicity: readings should not reverse direction unless the needle visibly reverses in the video. Small jitter from parallax or blur may be smoothed; if unsure, reflect it in confidence.
#    - Set confidence (0.0–1.0) by: visibility of scale and needle, alignment of chronometer with ts_ms, and consistency with neighboring readings. Lower confidence if interpolating heavily or if the gauge is partially occluded.

# CONSTRAINT: Output a single JSON array only. No markdown, no explanation outside the array. Each element: {{"ts_ms": integer, "reading": float, "confidence": float}}.

# TASK: Produce a high-precision time-series of gauge readings from the video at the specified sampling instants.

# INSTRUMENT METADATA:
# - Gauge Type: {gauge_type} | Unit: {unit}
# - Graduation Interval: {graduation_interval}
# - Calibrated Range: [{reading_start}, {reading_end}]

# SAMPLING PROTOCOL:
# - Time reference: Every output ts_ms must align with the digital chronometer value (in ms) visible in the video. Use the chronometer as the ground truth for time; ignore video file timestamps.
# - Start: Begin from the first 200 ms integer multiple reached by the chronometer (e.g. if it starts at 5670 ms, first output entry at 5800 ms). Omit any earlier frames.
# - Interval: One reading every 200 ms by chronometer (e.g. 5800, 6000, 6200, …).
# - End: Continue until the video ends, always using chronometer values for ts_ms.

# RESPONSE REQUIREMENT:
# Output only one JSON array. Each entry: {{"ts_ms": integer, "reading": float, "confidence": float}}. No other text before or after.
# '''
