# %% [markdown]
# # Call Gemini — Gauge Video Inference
#
# Runs Gemini on all videos under `Dataset_0508/<GaugeName>/` (all subdirectories). **Only edit the CONFIG cell.**

# %%
# ============================
# CONFIG — edit this cell only
# ============================
GAUGE_IDS        = [1, 2, 3]                                          # gauges to run
MODEL_NAMES      = ["gemini-3-flash-preview", "gemini-3-pro-preview"] # models to run
STRATEGIES       = ["cot", "naive"]                                   # prompt strategies
INCLUDE_THOUGHTS = True                                               # save thinking_process column in output

# %%
import os, time
from itertools import product
from google import genai
from google.genai import types
import pandas as pd

_GAUGE_CONFIG = {
    1: {
        "name":      "1.- Analog Dial Gauge",
        "video_dir": "Dataset_0508/1.- Analog Dial Gauge",
        "label_ref": "Dataset_0508/metadata/gauge_1_metadata.xlsx",
    },
    2: {
        "name":      "2.- Analog Depth Gauge",
        "video_dir": "Dataset_0508/2.- Analog Depth Gauge",
        "label_ref": "Dataset_0508/metadata/gauge_2_metadata.xlsx",
    },
    3: {
        "name":      "3.- Analog Depth Gauge_without vernier",
        "video_dir": "Dataset_0508/3.- Analog Depth Gauge_without vernier",
        "label_ref": "Dataset_0508/metadata/gauge_3_metadata.xlsx",
    },
}

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

MAX_RETRIES = 3
RETRY_DELAY = 10  # seconds

for GAUGE_ID, MODEL_NAME, PROMPT_STRATEGY in product(GAUGE_IDS, MODEL_NAMES, STRATEGIES):
    print(f"\n{'#'*60}")
    print(f"# GAUGE={GAUGE_ID}  MODEL={MODEL_NAME}  STRATEGY={PROMPT_STRATEGY}")
    print(f"{'#'*60}")

    cfg          = _GAUGE_CONFIG[GAUGE_ID]
    naive_suffix = "_naive" if PROMPT_STRATEGY == "naive" else ""
    output_dir   = f"Results_0508/Gemini/{cfg['name']}_{MODEL_NAME}{naive_suffix}"
    os.makedirs(output_dir, exist_ok=True)

    _meta = pd.read_excel(cfg["label_ref"], sheet_name="Metadata")
    _meta.set_index("Column (Header)", inplace=True)
    gauge_type          = _meta.loc["type",                    "Content / Example"]
    unit                = _meta.loc["unit",                    "Content / Example"]
    reading_start       = float(_meta.loc["manufacturer_range_min", "Content / Example"])
    reading_end         = float(_meta.loc["manufacturer_range_max", "Content / Example"])
    graduation_interval = _meta.loc["graduation_interval",    "Content / Example"]

    video_files = []
    for dirpath, _, filenames in os.walk(cfg["video_dir"]):
        for fname in sorted(filenames):
            if fname.endswith(".mp4"):
                video_files.append(os.path.join(dirpath, fname))
    print(f"Found {len(video_files)} videos under {cfg['video_dir']}")

    # ============================
    # PROMPTS
    # ============================
    _cot_message = f'''ROLE: Expert Industrial Metrology Assistant

PROTOCOL: See-Think-Confirm
1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
CONSTRAINT: Output JSON only. Format: {{"ts_ms": integer, "reading": float, "confidence": float}}
TASK: Extract a high-precision time-series of readings from the video.

INSTRUMENT METADATA:
- Gauge Type: {gauge_type} | Unit: {unit}
- Graduation Interval: {graduation_interval}
- Calibrated Range: [{reading_start}, {reading_end}]

SAMPLING PROTOCOL:
- Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
- Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
- Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...).
- Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.

RESPONSE REQUIREMENT:
Output a single JSON array where each entry contains: {{"ts_ms": integer, "reading": float, "confidence": float}}'''

    _naive_message = f'''ROLE: Expert Industrial Metrology Assistant

TASK: Read the analog gauge values from the video at specific time intervals.

INSTRUMENT METADATA:
- Gauge Type: {gauge_type} | Unit: {unit}
- Graduation Interval: {graduation_interval}
- Calibrated Range: [{reading_start}, {reading_end}]

SAMPLING REQUIREMENTS:
- Use the digital chronometer shown in the video for timing.
- Start reading from the first 200ms integer increment.
- Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
- Continue until the video ends.

OUTPUT FORMAT:
Return only a JSON array of objects: {{"ts_ms": integer, "reading": float, "confidence": float}}'''

    message = _cot_message if PROMPT_STRATEGY == "cot" else _naive_message
    print(message)

    # ============================
    # INFERENCE LOOP
    # ============================
    for video_path in video_files:
        rel    = os.path.relpath(video_path, cfg["video_dir"])
        seq_id = rel.replace(os.sep, "_").replace(".mp4", "")

        output_file = os.path.join(output_dir, f"{seq_id}_Raw_Results.xlsx")
        if os.path.exists(output_file):
            print(f"Skipping: {seq_id}")
            continue

        print(f"\n{'='*20} Processing: {seq_id} {'='*20}")
        program_start_time = time.time()

        print("Uploading...")
        myfile = client.files.upload(file=video_path)
        while True:
            status = client.files.get(name=myfile.name)
            if status.state == "ACTIVE":
                break
            if status.state == "FAILED":
                raise Exception(f"Upload failed: {video_path}")
            print("Waiting for processing...")
            time.sleep(5)

        # fps=1 (1 frame per second), consistent with GPT's FRAME_INTERVAL_SEC=1.0
        video_part = types.Part(
            file_data=types.FileData(file_uri=myfile.uri, mime_type="video/mp4"),
            video_metadata=types.VideoMetadata(fps=1),
        )

        print("Generating...")
        response = None
        for attempt in range(1, MAX_RETRIES + 1):
            try:
                response = client.models.generate_content(
                    model=MODEL_NAME,
                    contents=[video_part, message],
                    config=types.GenerateContentConfig(
                        temperature=0.0,
                        thinking_config=types.ThinkingConfig(
                            thinking_level="high",
                            include_thoughts=INCLUDE_THOUGHTS,
                        ),
                    ),
                )
                break
            except Exception as e:
                print(f"Attempt {attempt}/{MAX_RETRIES} failed: {e}")
                if attempt < MAX_RETRIES:
                    print(f"Retrying in {RETRY_DELAY}s...")
                    time.sleep(RETRY_DELAY)
                else:
                    print(f"All retries exhausted. Skipping {seq_id}.")

        if response is None:
            continue

        print(response.text)

        total_duration = time.time() - program_start_time
        row = {
            "sequence_id":        seq_id,
            "raw_model_response": response.text,
            "total_duration_sec": round(total_duration, 2),
            "model_name":         MODEL_NAME,
        }
        if INCLUDE_THOUGHTS:
            parts = response.candidates[0].content.parts
            row["thinking_process"] = next((p.text for p in parts if p.thought), "")

        pd.DataFrame([row]).to_excel(output_file, index=False)
        print(f"Saved: {output_file}")
# Out:
# ############################################################
# # GAUGE=1  MODEL=gemini-3-flash-preview  STRATEGY=cot
# ############################################################
# Found 18 videos under Dataset_0508/1.- Analog Dial Gauge
# ROLE: Expert Industrial Metrology Assistant
#
# PROTOCOL: See-Think-Confirm
# 1. SEE: Localize gauge boundaries. Identify [0%] and [100%] markers.
# 2. THINK: Synchronize needle position with the in-band digital clock. Calculate velocity (ΔReading/ΔTime). Use 'Thought Signatures' to maintain temporal state between frames.
# 3. CONFIRM: Verify that the reading is within [min, max] and follows physical monotonicity relative to previous frames.
# CONSTRAINT: Output JSON only. Format: {"ts_ms": integer, "reading": float, "confidence": float}
# TASK: Extract a high-precision time-series of readings from the video.
#
# INSTRUMENT METADATA:
# - Gauge Type: Circular | Unit: mm
# - Graduation Interval: 0.01
# - Calibrated Range: [0.0, 10.0]
#
# SAMPLING PROTOCOL:
# - Absolute Time Reference: Every 'ts_ms' in your output must correspond to the EXACT numerical value shown on the digital chronometer in the frame.
# - Starting Point: The chronometer in this video starts at a non-zero value. Ignore any frames before the timer reaches the first 200ms integer increment (e.g., if the timer starts at 5670ms, your first entry should be at 5800ms).
# - Sampling Interval: Provide one reading every 200ms based on the chronometer's increments (e.g., 5800, 6000, 6200...).
# - Duration: Continue this sequence until the video ends, strictly following the chronometer's values, regardless of the video file's elapsed time.
#
# RESPONSE REQUIREMENT:
# Output a single JSON array where each entry contains: {"ts_ms": integer, "reading": float, "confidence": float}
# Skipping: DOWN_DOWN_V1_5 divisions_per_second
# Skipping: DOWN_DOWN_V2_10 divisions_per_second
# Skipping: DOWN_DOWN_V3_17 divisions_per_second
# Skipping: DOWN_DOWN_V4_33 divisions_per_second
# Skipping: DOWN_DOWN_V5_50 divisions_per_second
# Skipping: DOWN_DOWN_V6_100 divisions_per_second
# Skipping: UP_UP_V1_5 divisions_per_second
# Skipping: UP_UP_V2_10 divisions_per_second
# Skipping: UP_UP_V3_17 divisions_per_second
# Skipping: UP_UP_V4_33 divisions_per_second
# Skipping: UP_UP_V5_50 divisions_per_second
# Skipping: UP_UP_V6_100 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V1_5 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V2_10 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V3_17 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V4_33 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V5_50 divisions_per_second
# Skipping: UP_DOWN_UP-DOWN_V6_100 divisions_per_second
#
# ############################################################
# # GAUGE=1  MODEL=gemini-3-flash-preview  STRATEGY=naive
# ############################################################
# Found 18 videos under Dataset_0508/1.- Analog Dial Gauge
# ROLE: Expert Industrial Metrology Assistant
#
# TASK: Read the analog gauge values from the video at specific time intervals.
#
# INSTRUMENT METADATA:
# - Gauge Type: Circular | Unit: mm
# - Graduation Interval: 0.01
# - Calibrated Range: [0.0, 10.0]
#
# SAMPLING REQUIREMENTS:
# - Use the digital chronometer shown in the video for timing.
# - Start reading from the first 200ms integer increment.
# - Provide one reading every 200ms (e.g., 5800, 6000, 6200...).
# - Continue until the video ends.
#
# OUTPUT FORMAT:
# Return only a JSON array of objects: {"ts_ms": integer, "reading": float, "confidence": float}
# Skipping: DOWN_DOWN_V1_5 divisions_per_second
# Skipping: DOWN_DOWN_V2_10 divisions_per_second
# Skipping: DOWN_DOWN_V3_17 divisions_per_second
# Skipping: DOWN_DOWN_V4_33 divisions_per_second
# Skipping: DOWN_DOWN_V5_50 divisions_per_second
# Skipping: DOWN_DOWN_V6_100 divisions_per_second
# Skipping: UP_UP_V1_5 divisions_per_second
#
# ==================== Processing: UP_UP_V2_10 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2200, "reading": 0.100, "confidence": 0.9},
#   {"ts_ms": 2400, "reading": 0.101, "confidence": 0.9},
#   {"ts_ms": 2600, "reading": 0.102, "confidence": 0.9},
#   {"ts_ms": 2800, "reading": 0.102, "confidence": 0.9},
#   {"ts_ms": 3000, "reading": 0.103, "confidence": 0.9},
#   {"ts_ms": 3200, "reading": 0.104, "confidence": 0.9},
#   {"ts_ms": 3400, "reading": 0.104, "confidence": 0.9},
#   {"ts_ms": 3600, "reading": 0.105, "confidence": 0.9},
#   {"ts_ms": 3800, "reading": 0.106, "confidence": 0.9},
#   {"ts_ms": 4000, "reading": 0.106, "confidence": 0.9},
#   {"ts_ms": 4200, "reading": 0.107, "confidence": 0.9},
#   {"ts_ms": 4400, "reading": 0.108, "confidence": 0.9},
#   {"ts_ms": 4600, "reading": 0.108, "confidence": 0.9},
#   {"ts_ms": 4800, "reading": 0.109, "confidence": 0.9},
#   {"ts_ms": 5000, "reading": 0.110, "confidence": 0.9},
#   {"ts_ms": 5200, "reading": 0.110, "confidence": 0.9},
#   {"ts_ms": 5400, "reading": 0.111, "confidence": 0.9},
#   {"ts_ms": 5600, "reading": 0.111, "confidence": 0.9},
#   {"ts_ms": 5800, "reading": 0.111, "confidence": 0.9},
#   {"ts_ms": 6000, "reading": 0.112, "confidence": 0.9},
#   {"ts_ms": 6200, "reading": 0.112, "confidence": 0.9},
#   {"ts_ms": 6400, "reading": 0.113, "confidence": 0.9},
#   {"ts_ms": 6600, "reading": 0.113, "confidence": 0.9},
#   {"ts_ms": 6800, "reading": 0.113, "confidence": 0.9},
#   {"ts_ms": 7000, "reading": 0.114, "confidence": 0.9},
#   {"ts_ms": 7200, "reading": 0.114, "confidence": 0.9},
#   {"ts_ms": 7400, "reading": 0.115, "confidence": 0.9},
#   {"ts_ms": 7600, "reading": 0.115, "confidence": 0.9},
divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_UP_V3_17 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 0.01, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 0.03, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 0.05, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 0.07, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 0.09, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 0.11, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 0.13, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 0.15, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 0.17, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 0.19, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 0.21, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 0.23, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 0.25, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 0.27, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 0.29, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 0.31, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 0.33, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 0.35, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 0.37, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 0.39, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 0.41, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 0.43, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 0.45, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 0.47, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 0.49, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 0.51, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 0.53, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 0.55, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 0.57, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 0.59, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 0.61, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 0.63, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 0.65, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 0.67, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 0.69, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 0.71, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 0.73, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 0.75, "confidence": 1.0},
, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 3200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 3400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 3600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 3800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 4000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 4200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 4400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 4600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 4800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 5000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 5200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 5400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 5600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 5800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 6000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 6200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 6400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 6600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 6800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 7000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 7200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 7400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 7600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 7800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 8000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 8200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 8400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 8600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 8800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 9000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 9200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 9400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 9600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 9800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 10000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 10200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 10400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 10600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 10800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 11000, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 11200, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 11400, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 11600, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 11800, "reading": 0.0, "confidence": 0.9},
#   {"ts_ms": 12000, "reading": 0.0, "confidence": 0.9}
# ]
# ```
# Saved: Results_0508/Gemini/1.- Analog Dial Gauge_gemini-3-flash-preview_naive\UP_UP_V5_50 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_UP_V6_100 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Generating...
# ```json
# [{"ts_ms": 2000, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 2200, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 2400, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 2600, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 2800, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 3000, "reading": 0.0, "confidence": 0.95}, {"ts_ms": 3200, "reading": 0.1, "confidence": 0.95}, {"ts_ms": 3400, "reading": 0.2, "confidence": 0.95}, {"ts_ms": 3600, "reading": 0.3, "confidence": 0.95}, {"ts_ms": 3800, "reading": 0.4, "confidence": 0.95}, {"ts_ms": 4000, "reading": 0.5, "confidence": 0.95}, {"ts_ms": 4200, "reading": 0.6, "confidence": 0.95}, {"ts_ms": 4400, "reading": 0.7, "confidence": 0.95}, {"ts_ms": 4600, "reading": 0.8, "confidence": 0.95}, {"ts_ms": 4800, "reading": 0.9, "confidence": 0.95}, {"ts_ms": 5000, "reading": 1.0, "confidence": 0.95}, {"ts_ms": 5200, "reading": 1.1, "confidence": 0.95}, {"ts_ms": 5400, "reading": 1.2, "confidence": 0.95}, {"ts_ms": 5600, "reading": 1.3, "confidence": 0.95}, {"ts_ms": 5800, "reading": 1.4, "confidence": 0.95}, {"ts_ms": 6000, "reading": 1.5, "confidence": 0.95}, {"ts_ms": 6200, "reading": 1.6, "confidence": 0.95}, {"ts_ms": 6400, "reading": 1.7, "confidence": 0.95}, {"ts_ms": 6600, "reading": 1.8, "confidence": 0.95}, {"ts_ms": 6800, "reading": 1.9, "confidence": 0.95}, {"ts_ms": 7000, "reading": 2.0, "confidence": 0.95}, {"ts_ms": 7200, "reading": 2.1, "confidence": 0.95}, {"ts_ms": 7400, "reading": 2.2, "confidence": 0.95}, {"ts_ms": 7600, "reading": 2.3, "confidence": 0.95}, {"ts_ms": 7800, "reading": 2.4, "confidence": 0.95}, {"ts_ms": 8000, "reading": 2.5, "confidence": 0.95}, {"ts_ms": 8200, "reading": 2.6, "confidence": 0.95}, {"ts_ms": 8400, "reading": 2.7, "confidence": 0.95}, {"ts_ms": 8600, "reading": 2.8, "confidence": 0.95}, {"ts_ms": 8800, "reading": 2.9, "confidence": 0.95}, {"ts_ms": 9000, "reading": 3.0, "confidence": 0.95}, {"ts_ms": 9200, "reading": 3.1, "confidence": 0.95}, {"ts_ms": 9400, "reading": 3.2, "confidence": 0.95}, {"ts_ms": 9600, "reading": 3.3, "confidence": 0.95}, {"ts_ms": 9800, "reading": 3.4, "confidence": 0.95}, {"ts_ms": 10000, "reading": 3.5, "confidence": 0.95}]
# ```
# Saved: Results_0508/Gemini/1.- Analog Dial Gauge_gemini-3-flash-preview_naive\UP_UP_V6_100 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_DOWN_UP-DOWN_V1_5 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [{"ts_ms": 2000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 2200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 2400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 2600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 2800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 3000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 3200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 3400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 3600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 3800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 4000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 4200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 4400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 4600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 4800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 5000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 5200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 5400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 5600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 5800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 6000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 6200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 6400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 6600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 6800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 7000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 7200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 7400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 7600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 7800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 8000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 8200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 8400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 8600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 8800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 9000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 9200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 9400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 9600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 9800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 10000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 10200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 10400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 10600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 10800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 11000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 11200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 11400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 11600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 11800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 12000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 12200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 12400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 12600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 12800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 13000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 13200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 13400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 13600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 13800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 14000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 14200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 14400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 14600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 14800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 15000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 15200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 15400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 15600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 15800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 16000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 16200, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 16400, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 16600, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 16800, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 17000, "reading": 0.0, "confidence": 1.0}, {"ts_ms": 1 ...
# ```
# Saved: Results_0508/Gemini/1.- Analog Dial Gauge_gemini-3-flash-preview_naive\UP_DOWN_UP-DOWN_V1_5 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_DOWN_UP-DOWN_V2_10 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 12000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 12200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 12400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 12600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 12800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 13000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 13200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 13400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 13600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 13800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 14000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 14200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 14400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 14600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 14800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 15000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 15200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 15400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 15600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 15800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 16000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 16200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 16400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 16600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 16800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 17000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 17200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 17400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 17600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 17800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 18000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 18200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 18400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 18600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 18800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 19000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 19200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 19400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 19600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 19800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 20000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 20200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 20400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 20600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 20800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 21000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 21200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 21400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 21600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 21800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 22000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 22200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 22400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 22600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 22800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 23000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 23200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 23400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 23600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 23800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 24000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 24200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 24400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 24600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 24800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 25000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 25200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 25400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 25600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 25800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 26000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 26200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 26400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 26600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 26800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 27000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 27200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 27400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 27600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 27800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 28000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 28200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 28400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 28600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 28800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 29000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 29200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 29400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 29600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 29800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 30000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 30200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 30400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 30600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 30800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 31000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 31200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 31400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 31600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 31800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 32000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 32200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 32400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 32600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 32800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 33000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 33200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 33400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 33600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 33800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 34000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 34200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 34400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 34600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 34800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 35000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 35200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 35400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 35600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 35800, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 36000, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 36200, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 36400, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 36600, "reading": 0.0, "confidence": 1.0},
#   {"ts_ms": 36800, "reading": 0.0, "confidence": 1.0}
# ]
# ```
# Saved: Results_0508/Gemini/1.- Analog Dial Gauge_gemini-3-flash-preview_naive\UP_DOWN_UP-DOWN_V2_10 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_DOWN_UP-DOWN_V3_17 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [{"ts_ms": 2200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 2400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 2600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 2800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 3000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 3200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 3400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 3600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 3800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 4000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 4200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 4400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 4600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 4800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 5000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 5200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 5400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 5600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 5800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 6000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 6200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 6400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 6600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 6800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 7000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 7200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 7400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 7600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 7800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 8000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 8200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 8400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 8600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 8800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 9000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 9200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 9400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 9600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 9800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 10000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 10200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 10400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 10600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 10800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 11000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 11200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 11400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 11600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 11800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 12000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 12200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 12400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 12600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 12800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 13000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 13200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 13400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 13600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 13800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 14000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 14200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 14400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 14600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 14800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 15000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 15200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 15400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 15600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 15800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 16000, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 16200, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 16400, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 16600, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 16800, "reading": 4.45, "confidence": 1.0}, {"ts_ms": 17000, "reading": 4.45, "confide ...
# ```
# Saved: Results_0508/Gemini/1.- Analog Dial Gauge_gemini-3-flash-preview_naive\UP_DOWN_UP-DOWN_V3_17 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: UP_DOWN_UP-DOWN_V4_33 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [
# ...
#   {"ts_ms": 9200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 12000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 12200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 12400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 12600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 12800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 13000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 13200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 13400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 13600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 13800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 14000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 14200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 14400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 14600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 14800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 15000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 15200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 15400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 15600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 15800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 16000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 16200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 16400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 16600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 16800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 17000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 17200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 17400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 17600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 17800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 18000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 18200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 18400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 18600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 18800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 19000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 19200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 19400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 19600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 19800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 20000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 20200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 20400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 20600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 20800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 21000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 21200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 21400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 21600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 21800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 22000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 22200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 22400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 22600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 22800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 23000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 23200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 23400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 23600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 23800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 24000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 24200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 24400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 24600, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 24800, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 25000, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 25200, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 25400, "reading": 24.5, "confidence": 1.0},
#   {"ts_ms": 25600, "reading": 24.5, "confidence": 1.0}
# ]
# ```
# Saved: Results_0508/Gemini/3.- Analog Depth Gauge_without vernier_gemini-3-pro-preview_naive\OPENING-CLOSING_OPENING-CLOSING_V3_1.7 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: OPENING-CLOSING_OPENING-CLOSING_V4_2.5 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 12000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 12200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 12400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 12600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 12800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 13000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 13200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 13400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 13600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 13800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 14000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 14200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 14400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 14600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 14800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 15000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 15200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 15400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 15600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 15800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 16000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 16200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 16400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 16600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 16800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 17000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 17200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 17400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 17600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 17800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 18000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 18200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 18400, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 18600, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 18800, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 19000, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 19200, "reading": 28.0, "confidence": 1.0},
#   {"ts_ms": 19400, "reading": 28.0, "confidence": 1.0}
# ]
# ```
# Saved: Results_0508/Gemini/3.- Analog Depth Gauge_without vernier_gemini-3-pro-preview_naive\OPENING-CLOSING_OPENING-CLOSING_V4_2.5 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: OPENING-CLOSING_OPENING-CLOSING_V5_5 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 2600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 2800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 3000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 3200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 3400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 3600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 3800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 4000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 4200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 4400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 4600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 4800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 5000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 5200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 5400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 5600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 5800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 6000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 6200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 6400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 6600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 6800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 7000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 7200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 7400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 7600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 7800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 8000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 8200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 8400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 8600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 8800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 9000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 9200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 9400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 9600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 9800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 10000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 10200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 10400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 10600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 10800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 11000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 11200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 11400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 11600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 11800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 12000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 12200, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 12400, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 12600, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 12800, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 13000, "reading": 24.0, "confidence": 1.0},
#   {"ts_ms": 13200, "reading": 24.0, "confidence": 1.0}
# ]
# ```
# Saved: Results_0508/Gemini/3.- Analog Depth Gauge_without vernier_gemini-3-pro-preview_naive\OPENING-CLOSING_OPENING-CLOSING_V5_5 divisions_per_second_Raw_Results.xlsx
#
# ==================== Processing: OPENING-CLOSING_OPENING-CLOSING_V6_10 divisions_per_second ====================
# Uploading...
# Waiting for processing...
# Generating...
# ```json
# [
#   {"ts_ms": 2800, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 3000, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 3200, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 3400, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 3600, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 3800, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 4000, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 4200, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 4400, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 4600, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 4800, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 5000, "reading": 28.0, "confidence": 0.9},
#   {"ts_ms": 5200, "reading": 30.6, "confidence": 0.8},
#   {"ts_ms": 5400, "reading": 33.2, "confidence": 0.8},
#   {"ts_ms": 5600, "reading": 35.8, "confidence": 0.8},
#   {"ts_ms": 5800, "reading": 38.4, "confidence": 0.8},
#   {"ts_ms": 6000, "reading": 41.0, "confidence": 0.8},
#   {"ts_ms": 6200, "reading": 43.6, "confidence": 0.8},
#   {"ts_ms": 6400, "reading": 46.2, "confidence": 0.8},
#   {"ts_ms": 6600, "reading": 48.8, "confidence": 0.8},
#   {"ts_ms": 6800, "reading": 51.4, "confidence": 0.8},
#   {"ts_ms": 7000, "reading": 54.0, "confidence": 0.8},
#   {"ts_ms": 7200, "reading": 56.6, "confidence": 0.8},
#   {"ts_ms": 7400, "reading": 59.2, "confidence": 0.8},
#   {"ts_ms": 7600, "reading": 61.8, "confidence": 0.8},
#   {"ts_ms": 7800, "reading": 64.4, "confidence": 0.8},
#   {"ts_ms": 8000, "reading": 67.0, "confidence": 0.8},
#   {"ts_ms": 8200, "reading": 69.6, "confidence": 0.8},
#   {"ts_ms": 8400, "reading": 72.2, "confidence": 0.8},
#   {"ts_ms": 8600, "reading": 74.8, "confidence": 0.8},
#   {"ts_ms": 8800, "reading": 77.4, "confidence": 0.8},
#   {"ts_ms": 9000, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 9200, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 9400, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 9600, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 9800, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 10000, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 10200, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 10400, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 10600, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 10800, "reading": 80.0, "confidence": 0.9},
#   {"ts_ms": 11000, "reading": 80.0, "confidence": 0.9}
# ]
# ```
# Saved: Results_0508/Gemini/3.- Analog Depth Gauge_without vernier_gemini-3-pro-preview_naive\OPENING-CLOSING_OPENING-CLOSING_V6_10 divisions_per_second_Raw_Results.xlsx
